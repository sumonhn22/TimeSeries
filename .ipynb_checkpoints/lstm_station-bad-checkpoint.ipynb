# %%
# Time series :

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/station.csv \
    -O /tmp/station.csv
# Out:
# --2021-12-30 22:53:16--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/station.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.112.128, 74.125.124.128, 172.217.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.112.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6979 (6.8K) [application/octet-stream]
# Saving to: ‘/tmp/station.csv’
#
# /tmp/station.csv    100%[===================>]   6.82K  --.-KB/s    in 0s
#
# 2021-12-30 22:53:16 (41.3 MB/s) - ‘/tmp/station.csv’ saved [6979/6979]

# %% [markdown]
# ### Data preprocessing

# %%
def get_data():
    data_file = "/tmp/station.csv"
    f = open(data_file)
    data = f.read()
    f.close()
    lines = data.split('\n')
    header = lines[0].split(',')
    lines = lines[1:]
    temperatures=[]
    for line in lines:
        if line:
            linedata = line.split(',')
            linedata = linedata[1:13]
            for item in linedata:
                if item:
                    temperatures.append(float(item))

    series = np.asarray(temperatures)
    time = np.arange(len(temperatures), dtype="float32")      
    return time, series

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
time, series = get_data()
# print(series)

# %%
mean = series.mean(axis=0)
series-=mean
std = series.std(axis=0)
series/=std
split_time = 780
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  series = tf.expand_dims(series, axis=-1)
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 20
batch_size = 20
shuffle_buffer_size = 20

dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
valid_dataset = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(24, input_shape=[None, 1], return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(24)),
  tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.SGD(lr=1e-4, momentum=0.7)
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer, metrics=["mae"])
history = model.fit(dataset, epochs=50,  verbose=1, validation_data=valid_dataset)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/50
# 38/38 [==============================] - 27s 95ms/step - loss: 0.4546 - mae: 0.8651 - val_loss: 0.5231 - val_mae: 0.9348
# Epoch 2/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4538 - mae: 0.8641 - val_loss: 0.5222 - val_mae: 0.9337
# Epoch 3/50
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4529 - mae: 0.8631 - val_loss: 0.5213 - val_mae: 0.9326
# Epoch 4/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4521 - mae: 0.8620 - val_loss: 0.5205 - val_mae: 0.9315
# Epoch 5/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4512 - mae: 0.8610 - val_loss: 0.5196 - val_mae: 0.9305
# Epoch 6/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4504 - mae: 0.8600 - val_loss: 0.5188 - val_mae: 0.9294
# Epoch 7/50
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4496 - mae: 0.8590 - val_loss: 0.5179 - val_mae: 0.9283
# Epoch 8/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4487 - mae: 0.8580 - val_loss: 0.5171 - val_mae: 0.9272
# Epoch 9/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4479 - mae: 0.8570 - val_loss: 0.5162 - val_mae: 0.9262
# Epoch 10/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4471 - mae: 0.8559 - val_loss: 0.5153 - val_mae: 0.9251
# Epoch 11/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4463 - mae: 0.8549 - val_loss: 0.5145 - val_mae: 0.9240
# Epoch 12/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4454 - mae: 0.8539 - val_loss: 0.5136 - val_mae: 0.9229
# Epoch 13/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4446 - mae: 0.8529 - val_loss: 0.5128 - val_mae: 0.9219
# Epoch 14/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4438 - mae: 0.8519 - val_loss: 0.5120 - val_mae: 0.9208
# Epoch 15/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4430 - mae: 0.8509 - val_loss: 0.5111 - val_mae: 0.9197
# Epoch 16/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4422 - mae: 0.8499 - val_loss: 0.5103 - val_mae: 0.9187
# Epoch 17/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4413 - mae: 0.8489 - val_loss: 0.5094 - val_mae: 0.9176
# Epoch 18/50
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4405 - mae: 0.8479 - val_loss: 0.5086 - val_mae: 0.9165
# Epoch 19/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4397 - mae: 0.8470 - val_loss: 0.5077 - val_mae: 0.9155
# Epoch 20/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4389 - mae: 0.8460 - val_loss: 0.5069 - val_mae: 0.9144
# Epoch 21/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4381 - mae: 0.8450 - val_loss: 0.5061 - val_mae: 0.9133
# Epoch 22/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4373 - mae: 0.8440 - val_loss: 0.5052 - val_mae: 0.9123
# Epoch 23/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4365 - mae: 0.8430 - val_loss: 0.5044 - val_mae: 0.9112
# Epoch 24/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4357 - mae: 0.8420 - val_loss: 0.5035 - val_mae: 0.9101
# Epoch 25/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4349 - mae: 0.8410 - val_loss: 0.5027 - val_mae: 0.9091
# Epoch 26/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4340 - mae: 0.8400 - val_loss: 0.5018 - val_mae: 0.9080
# Epoch 27/50
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4332 - mae: 0.8391 - val_loss: 0.5010 - val_mae: 0.9070
# Epoch 28/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4324 - mae: 0.8381 - val_loss: 0.5001 - val_mae: 0.9059
# Epoch 29/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4316 - mae: 0.8371 - val_loss: 0.4993 - val_mae: 0.9049
# Epoch 30/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4308 - mae: 0.8361 - val_loss: 0.4985 - val_mae: 0.9038
# Epoch 31/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4300 - mae: 0.8351 - val_loss: 0.4976 - val_mae: 0.9028
# Epoch 32/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4292 - mae: 0.8341 - val_loss: 0.4968 - val_mae: 0.9018
# Epoch 33/50
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4284 - mae: 0.8332 - val_loss: 0.4959 - val_mae: 0.9008
# Epoch 34/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4276 - mae: 0.8322 - val_loss: 0.4951 - val_mae: 0.8998
# Epoch 35/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4268 - mae: 0.8312 - val_loss: 0.4942 - val_mae: 0.8988
# Epoch 36/50
# 38/38 [==============================] - 1s 32ms/step - loss: 0.4260 - mae: 0.8302 - val_loss: 0.4934 - val_mae: 0.8978
# Epoch 37/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4251 - mae: 0.8292 - val_loss: 0.4925 - val_mae: 0.8968
# Epoch 38/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4243 - mae: 0.8283 - val_loss: 0.4917 - val_mae: 0.8957
# Epoch 39/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4235 - mae: 0.8273 - val_loss: 0.4908 - val_mae: 0.8947
# Epoch 40/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4227 - mae: 0.8263 - val_loss: 0.4900 - val_mae: 0.8937
# Epoch 41/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4219 - mae: 0.8253 - val_loss: 0.4891 - val_mae: 0.8927
# Epoch 42/50
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4211 - mae: 0.8243 - val_loss: 0.4882 - val_mae: 0.8916
# Epoch 43/50
# 38/38 [==============================] - 1s 34ms/step - loss: 0.4203 - mae: 0.8234 - val_loss: 0.4874 - val_mae: 0.8906
# Epoch 44/50
# 38/38 [==============================] - 1s 36ms/step - loss: 0.4195 - mae: 0.8224 - val_loss: 0.4865 - val_mae: 0.8896
# Epoch 45/50
# 38/38 [==============================] - 2s 41ms/step - loss: 0.4186 - mae: 0.8214 - val_loss: 0.4856 - val_mae: 0.8886
# Epoch 46/50
# 38/38 [==============================] - 1s 36ms/step - loss: 0.4178 - mae: 0.8204 - val_loss: 0.4848 - val_mae: 0.8875
# Epoch 47/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4170 - mae: 0.8194 - val_loss: 0.4839 - val_mae: 0.8865
# Epoch 48/50
# 38/38 [==============================] - 1s 37ms/step - loss: 0.4162 - mae: 0.8184 - val_loss: 0.4830 - val_mae: 0.8854
# Epoch 49/50
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4154 - mae: 0.8174 - val_loss: 0.4822 - val_mae: 0.8844
# Epoch 50/50
# 38/38 [==============================] - 1s 37ms/step - loss: 0.4145 - mae: 0.8164 - val_loss: 0.4813 - val_mae: 0.8833

# %%
def model_forecast(model, series, window_size):
    series = tf.expand_dims(series, axis=-1) 
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
forecast = model_forecast(model, series[split_time - window_size: -1], window_size)[:,0]

# %%
plt.figure(figsize=(10,6))
plot_series(time_valid, x_valid)
plot_series(time_valid, forecast)
plt.show()

plt.figure(figsize=(10,6))
plot_series(time_valid[-100:], x_valid[-100:])
plot_series(time_valid[-100:], forecast[-100:])
plt.show()

# %%
mae = tf.keras.metrics.mean_absolute_error(x_valid, forecast).numpy()
print(mae)
# Out:
# 0.8818147

# %%
mae=history.history['mae']
loss=history.history['loss']
val_mae=history.history['val_mae']
val_loss=history.history['val_loss']
epochs=range(len(loss)) # Get number of epochs
#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
#plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
#plt.plot(epochs, val_mae, 'g')
plt.plot(epochs, val_loss, 'k')
plt.title('Training and Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Loss", "Validation Loss"])

plt.figure()
plt.show()
