# %% [markdown]
# #  Time series

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/station.csv \
    -O /tmp/station.csv
# Out:
# --2021-12-30 22:09:52--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/station.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.195.128, 173.194.197.128, 173.194.198.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6979 (6.8K) [application/octet-stream]
# Saving to: ‘/tmp/station.csv’
#
# /tmp/station.csv    100%[===================>]   6.82K  --.-KB/s    in 0s
#
# 2021-12-30 22:09:52 (61.9 MB/s) - ‘/tmp/station.csv’ saved [6979/6979]

# %%
def get_data():
    data_file = "/tmp/station.csv"
    f = open(data_file)
    data = f.read()
    f.close()
    lines = data.split('\n')
    header = lines[0].split(',')
    lines = lines[1:]
    temperatures=[]
    for line in lines:
        if line:
            linedata = line.split(',')
            linedata = linedata[1:13]
            for item in linedata:
                if item:
                    temperatures.append(float(item))

    series = np.asarray(temperatures)
    time = np.arange(len(temperatures), dtype="float32")      
    return time, series

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
time, series = get_data()
mean = series.mean(axis=0)
series-=mean
std = series.std(axis=0)
series/=std
split_time = 780
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  series = tf.expand_dims(series, axis=-1)
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 20
batch_size = 20
shuffle_buffer_size = 20

dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
valid_dataset = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

print('dataset shape=', dataset)
# Out:
# dataset shape= <PrefetchDataset shapes: ((None, None, 1), (None, 1)), types: (tf.float64, tf.float64)>

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.SimpleRNN(100, return_sequences=True, input_shape=[None, 1]),
    tf.keras.layers.SimpleRNN(100),
    tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.SGD(lr=1e-4, momentum=0.7)
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer, metrics=["mae"])
history = model.fit(dataset, epochs=100,  verbose=1, validation_data=valid_dataset)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/100
# 38/38 [==============================] - 3s 27ms/step - loss: 0.0928 - mae: 0.3361 - val_loss: 0.0719 - val_mae: 0.3068
# Epoch 2/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0606 - mae: 0.2750 - val_loss: 0.0601 - val_mae: 0.2821
# Epoch 3/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0580 - mae: 0.2698 - val_loss: 0.0576 - val_mae: 0.2775
# Epoch 4/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0567 - mae: 0.2670 - val_loss: 0.0567 - val_mae: 0.2760
# Epoch 5/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0556 - mae: 0.2640 - val_loss: 0.0563 - val_mae: 0.2753
# Epoch 6/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0545 - mae: 0.2616 - val_loss: 0.0556 - val_mae: 0.2741
# Epoch 7/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0536 - mae: 0.2593 - val_loss: 0.0556 - val_mae: 0.2740
# Epoch 8/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0527 - mae: 0.2571 - val_loss: 0.0553 - val_mae: 0.2735
# Epoch 9/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0519 - mae: 0.2552 - val_loss: 0.0549 - val_mae: 0.2725
# Epoch 10/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0512 - mae: 0.2534 - val_loss: 0.0546 - val_mae: 0.2717
# Epoch 11/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0505 - mae: 0.2517 - val_loss: 0.0545 - val_mae: 0.2713
# Epoch 12/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0498 - mae: 0.2501 - val_loss: 0.0541 - val_mae: 0.2703
# Epoch 13/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0493 - mae: 0.2486 - val_loss: 0.0538 - val_mae: 0.2694
# Epoch 14/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0487 - mae: 0.2472 - val_loss: 0.0535 - val_mae: 0.2686
# Epoch 15/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0482 - mae: 0.2459 - val_loss: 0.0533 - val_mae: 0.2680
# Epoch 16/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0476 - mae: 0.2446 - val_loss: 0.0527 - val_mae: 0.2665
# Epoch 17/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0471 - mae: 0.2434 - val_loss: 0.0525 - val_mae: 0.2661
# Epoch 18/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0467 - mae: 0.2422 - val_loss: 0.0524 - val_mae: 0.2658
# Epoch 19/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0462 - mae: 0.2412 - val_loss: 0.0522 - val_mae: 0.2653
# Epoch 20/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0458 - mae: 0.2402 - val_loss: 0.0521 - val_mae: 0.2651
# Epoch 21/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0454 - mae: 0.2392 - val_loss: 0.0516 - val_mae: 0.2639
# Epoch 22/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0450 - mae: 0.2382 - val_loss: 0.0515 - val_mae: 0.2638
# Epoch 23/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0447 - mae: 0.2373 - val_loss: 0.0514 - val_mae: 0.2634
# Epoch 24/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0443 - mae: 0.2365 - val_loss: 0.0510 - val_mae: 0.2623
# Epoch 25/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0439 - mae: 0.2355 - val_loss: 0.0508 - val_mae: 0.2619
# Epoch 26/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0436 - mae: 0.2346 - val_loss: 0.0508 - val_mae: 0.2616
# Epoch 27/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0433 - mae: 0.2339 - val_loss: 0.0507 - val_mae: 0.2613
# Epoch 28/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0430 - mae: 0.2330 - val_loss: 0.0502 - val_mae: 0.2599
# Epoch 29/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0427 - mae: 0.2323 - val_loss: 0.0503 - val_mae: 0.2602
# Epoch 30/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0424 - mae: 0.2315 - val_loss: 0.0499 - val_mae: 0.2591
# Epoch 31/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0421 - mae: 0.2309 - val_loss: 0.0498 - val_mae: 0.2586
# Epoch 32/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0418 - mae: 0.2301 - val_loss: 0.0496 - val_mae: 0.2580
# Epoch 33/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0416 - mae: 0.2294 - val_loss: 0.0496 - val_mae: 0.2580
# Epoch 34/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0413 - mae: 0.2288 - val_loss: 0.0495 - val_mae: 0.2575
# Epoch 35/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0411 - mae: 0.2280 - val_loss: 0.0491 - val_mae: 0.2563
# Epoch 36/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0409 - mae: 0.2273 - val_loss: 0.0491 - val_mae: 0.2563
# Epoch 37/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0406 - mae: 0.2268 - val_loss: 0.0491 - val_mae: 0.2559
# Epoch 38/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0404 - mae: 0.2262 - val_loss: 0.0490 - val_mae: 0.2556
# Epoch 39/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0402 - mae: 0.2255 - val_loss: 0.0487 - val_mae: 0.2547
# Epoch 40/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0400 - mae: 0.2250 - val_loss: 0.0485 - val_mae: 0.2542
# Epoch 41/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0398 - mae: 0.2243 - val_loss: 0.0484 - val_mae: 0.2537
# Epoch 42/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0396 - mae: 0.2238 - val_loss: 0.0482 - val_mae: 0.2530
# Epoch 43/100
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0394 - mae: 0.2233 - val_loss: 0.0483 - val_mae: 0.2531
# Epoch 44/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0392 - mae: 0.2228 - val_loss: 0.0480 - val_mae: 0.2522
# Epoch 45/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0390 - mae: 0.2224 - val_loss: 0.0482 - val_mae: 0.2528
# Epoch 46/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0388 - mae: 0.2218 - val_loss: 0.0480 - val_mae: 0.2519
# Epoch 47/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0386 - mae: 0.2212 - val_loss: 0.0480 - val_mae: 0.2517
# Epoch 48/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0385 - mae: 0.2209 - val_loss: 0.0477 - val_mae: 0.2509
# Epoch 49/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0383 - mae: 0.2203 - val_loss: 0.0477 - val_mae: 0.2507
# Epoch 50/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0382 - mae: 0.2199 - val_loss: 0.0476 - val_mae: 0.2504
# Epoch 51/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0380 - mae: 0.2194 - val_loss: 0.0476 - val_mae: 0.2501
# Epoch 52/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0378 - mae: 0.2189 - val_loss: 0.0474 - val_mae: 0.2498
# Epoch 53/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0377 - mae: 0.2186 - val_loss: 0.0475 - val_mae: 0.2495
# Epoch 54/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0375 - mae: 0.2182 - val_loss: 0.0472 - val_mae: 0.2490
# Epoch 55/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0374 - mae: 0.2178 - val_loss: 0.0473 - val_mae: 0.2489
# Epoch 56/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0373 - mae: 0.2175 - val_loss: 0.0473 - val_mae: 0.2488
# Epoch 57/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0371 - mae: 0.2169 - val_loss: 0.0470 - val_mae: 0.2478
# Epoch 58/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0370 - mae: 0.2167 - val_loss: 0.0471 - val_mae: 0.2479
# Epoch 59/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0368 - mae: 0.2163 - val_loss: 0.0471 - val_mae: 0.2479
# Epoch 60/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0367 - mae: 0.2160 - val_loss: 0.0471 - val_mae: 0.2474
# Epoch 61/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0366 - mae: 0.2156 - val_loss: 0.0469 - val_mae: 0.2470
# Epoch 62/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0364 - mae: 0.2152 - val_loss: 0.0471 - val_mae: 0.2472
# Epoch 63/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0363 - mae: 0.2149 - val_loss: 0.0468 - val_mae: 0.2465
# Epoch 64/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0362 - mae: 0.2146 - val_loss: 0.0467 - val_mae: 0.2458
# Epoch 65/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0361 - mae: 0.2142 - val_loss: 0.0468 - val_mae: 0.2459
# Epoch 66/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0360 - mae: 0.2139 - val_loss: 0.0467 - val_mae: 0.2457
# Epoch 67/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0358 - mae: 0.2135 - val_loss: 0.0466 - val_mae: 0.2453
# Epoch 68/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0357 - mae: 0.2133 - val_loss: 0.0464 - val_mae: 0.2445
# Epoch 69/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0356 - mae: 0.2129 - val_loss: 0.0465 - val_mae: 0.2446
# Epoch 70/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0355 - mae: 0.2125 - val_loss: 0.0465 - val_mae: 0.2445
# Epoch 71/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0354 - mae: 0.2122 - val_loss: 0.0463 - val_mae: 0.2439
# Epoch 72/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0353 - mae: 0.2120 - val_loss: 0.0464 - val_mae: 0.2441
# Epoch 73/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0352 - mae: 0.2116 - val_loss: 0.0463 - val_mae: 0.2437
# Epoch 74/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0351 - mae: 0.2114 - val_loss: 0.0465 - val_mae: 0.2440
# Epoch 75/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0350 - mae: 0.2111 - val_loss: 0.0462 - val_mae: 0.2431
# Epoch 76/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0349 - mae: 0.2109 - val_loss: 0.0463 - val_mae: 0.2432
# Epoch 77/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0348 - mae: 0.2105 - val_loss: 0.0461 - val_mae: 0.2428
# Epoch 78/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0347 - mae: 0.2102 - val_loss: 0.0462 - val_mae: 0.2428
# Epoch 79/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0346 - mae: 0.2100 - val_loss: 0.0462 - val_mae: 0.2428
# Epoch 80/100
# 38/38 [==============================] - 1s 32ms/step - loss: 0.0346 - mae: 0.2098 - val_loss: 0.0462 - val_mae: 0.2427
# Epoch 81/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0345 - mae: 0.2095 - val_loss: 0.0459 - val_mae: 0.2420
# Epoch 82/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0344 - mae: 0.2091 - val_loss: 0.0460 - val_mae: 0.2421
# Epoch 83/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0343 - mae: 0.2090 - val_loss: 0.0461 - val_mae: 0.2423
# Epoch 84/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0342 - mae: 0.2088 - val_loss: 0.0460 - val_mae: 0.2419
# Epoch 85/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0341 - mae: 0.2085 - val_loss: 0.0459 - val_mae: 0.2417
# Epoch 86/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0341 - mae: 0.2083 - val_loss: 0.0460 - val_mae: 0.2417
# Epoch 87/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0339 - mae: 0.2079 - val_loss: 0.0459 - val_mae: 0.2414
# Epoch 88/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0339 - mae: 0.2078 - val_loss: 0.0458 - val_mae: 0.2413
# Epoch 89/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0338 - mae: 0.2074 - val_loss: 0.0458 - val_mae: 0.2410
# Epoch 90/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0337 - mae: 0.2074 - val_loss: 0.0457 - val_mae: 0.2409
# Epoch 91/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0336 - mae: 0.2070 - val_loss: 0.0458 - val_mae: 0.2409
# Epoch 92/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0336 - mae: 0.2069 - val_loss: 0.0456 - val_mae: 0.2404
# Epoch 93/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0335 - mae: 0.2066 - val_loss: 0.0457 - val_mae: 0.2405
# Epoch 94/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0334 - mae: 0.2064 - val_loss: 0.0455 - val_mae: 0.2401
# Epoch 95/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0333 - mae: 0.2061 - val_loss: 0.0454 - val_mae: 0.2398
# Epoch 96/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0333 - mae: 0.2060 - val_loss: 0.0458 - val_mae: 0.2404
# Epoch 97/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0332 - mae: 0.2058 - val_loss: 0.0457 - val_mae: 0.2402
# Epoch 98/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0331 - mae: 0.2055 - val_loss: 0.0456 - val_mae: 0.2399
# Epoch 99/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0331 - mae: 0.2054 - val_loss: 0.0454 - val_mae: 0.2394
# Epoch 100/100
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0330 - mae: 0.2051 - val_loss: 0.0457 - val_mae: 0.2400

# %%
def model_forecast(model, series, window_size):
    series = tf.expand_dims(series, axis=-1) 
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
forecast = model_forecast(model, series[split_time - window_size: -1], window_size)[:,0]

# %%
plt.figure(figsize=(10,6))
plot_series(time_valid, x_valid)
plot_series(time_valid, forecast)
plt.show()

plt.figure(figsize=(10,6))
plot_series(time_valid[-100:], x_valid[-100:])
plot_series(time_valid[-100:], forecast[-100:])
plt.show()

# %%
mae = tf.keras.metrics.mean_absolute_error(x_valid, forecast).numpy()
print(mae)
# Out:
# 0.25087816

# %%
mae=history.history['mae']
loss=history.history['loss']
val_mae=history.history['val_mae']
val_loss=history.history['val_loss']
epochs=range(len(loss)) # Get number of epochs

#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
#plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
#plt.plot(epochs, val_mae, 'g')
plt.plot(epochs, val_loss, 'k')
plt.title('Training and Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Loss", "Validation Loss"])

plt.figure()
plt.show()
