# %% [markdown]
# # Time series
#
# ###  CNN, LSTM

# %%
#!pip install tensorflow==2.5.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Sunspots.csv
# !gdown --id 1bLnqPgwoSh6rHz_DKDdDeQyAyl8_nqT5
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bLnqPgwoSh6rHz_DKDdDeQyAyl8_nqT5
# To: /content/Sunspots.csv
# 100% 70.8k/70.8k [00:00<00:00, 51.2MB/s]

# %%
import csv
time_step = []
sunspots = []

with open('./Sunspots.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  for row in reader:
    sunspots.append(float(row[2]))
    time_step.append(int(row[0]))

# %%
series = np.array(sunspots)
time = np.array(time_step)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 60
batch_size = 100
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer=shuffle_buffer_size)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape=[None, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.Dense(32, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.Huber(), optimizer='adam', metrics=["mae"])
history = model.fit(train_set, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 8s 58ms/step - loss: 78.1784 - mae: 78.6735
# Epoch 2/200
# 30/30 [==============================] - 2s 56ms/step - loss: 67.0138 - mae: 67.5111
# Epoch 3/200
# 30/30 [==============================] - 2s 55ms/step - loss: 55.9610 - mae: 56.4577
# Epoch 4/200
# 30/30 [==============================] - 2s 55ms/step - loss: 36.1881 - mae: 36.6797
# Epoch 5/200
# 30/30 [==============================] - 2s 56ms/step - loss: 24.9120 - mae: 25.4042
# Epoch 6/200
# 30/30 [==============================] - 2s 56ms/step - loss: 20.0067 - mae: 20.4984
# Epoch 7/200
# 30/30 [==============================] - 2s 54ms/step - loss: 18.0233 - mae: 18.5147
# Epoch 8/200
# 30/30 [==============================] - 2s 55ms/step - loss: 17.2365 - mae: 17.7271
# Epoch 9/200
# 30/30 [==============================] - 2s 57ms/step - loss: 16.9451 - mae: 17.4355
# Epoch 10/200
# 30/30 [==============================] - 2s 55ms/step - loss: 16.8434 - mae: 17.3337
200
# 30/30 [==============================] - 2s 54ms/step - loss: 4.1181 - mae: 4.5373
# Epoch 112/200
# 30/30 [==============================] - 2s 54ms/step - loss: 4.9186 - mae: 5.3654
# Epoch 113/200
# 30/30 [==============================] - 2s 54ms/step - loss: 4.1697 - mae: 4.5966
# Epoch 114/200
# 30/30 [==============================] - 2s 53ms/step - loss: 4.0912 - mae: 4.5121
# Epoch 115/200
# 30/30 [==============================] - 2s 56ms/step - loss: 4.0695 - mae: 4.4888
# Epoch 116/200
# 30/30 [==============================] - 2s 55ms/step - loss: 4.1291 - mae: 4.5542
# Epoch 117/200
# 30/30 [==============================] - 2s 53ms/step - loss: 4.1040 - mae: 4.5267
# Epoch 118/200
# 30/30 [==============================] - 2s 56ms/step - loss: 4.0159 - mae: 4.4353
# Epoch 119/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.8570 - mae: 4.2696
# Epoch 120/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.9061 - mae: 4.3214
# Epoch 121/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8816 - mae: 4.2976
# Epoch 122/200
# 30/30 [==============================] - 2s 54ms/step - loss: 4.0977 - mae: 4.5211
# Epoch 123/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.8398 - mae: 4.2524
# Epoch 124/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.9104 - mae: 4.3293
# Epoch 125/200
# 30/30 [==============================] - 2s 55ms/step - loss: 4.0012 - mae: 4.4237
# Epoch 126/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8696 - mae: 4.2880
# Epoch 127/200
# 30/30 [==============================] - 2s 53ms/step - loss: 4.3327 - mae: 4.7652
# Epoch 128/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8235 - mae: 4.2420
# Epoch 129/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.6867 - mae: 4.0965
# Epoch 130/200
# 30/30 [==============================] - 2s 53ms/step - loss: 4.0740 - mae: 4.4992
# Epoch 131/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.7059 - mae: 4.1174
# Epoch 132/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.5650 - mae: 3.9666
# Epoch 133/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.6797 - mae: 4.0907
# Epoch 134/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8987 - mae: 4.3207
# Epoch 135/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8457 - mae: 4.2649
# Epoch 136/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.5679 - mae: 3.9725
# Epoch 137/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.5977 - mae: 4.0040
# Epoch 138/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.8602 - mae: 4.2782
# Epoch 139/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.7441 - mae: 4.1619
# Epoch 140/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.6645 - mae: 4.0788
# Epoch 141/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.7335 - mae: 4.1440
# Epoch 142/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.5925 - mae: 4.0038
# Epoch 143/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4668 - mae: 3.8681
# Epoch 144/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.5026 - mae: 3.9081
# Epoch 145/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.6537 - mae: 4.0702
# Epoch 146/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.5387 - mae: 3.9457
# Epoch 147/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4135 - mae: 3.8154
# Epoch 148/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4446 - mae: 3.8508
# Epoch 149/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4709 - mae: 3.8774
# Epoch 150/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.5349 - mae: 3.9472
# Epoch 151/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4045 - mae: 3.8088
# Epoch 152/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3740 - mae: 3.7745
# Epoch 153/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3627 - mae: 3.7619
# Epoch 154/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.6032 - mae: 4.0190
# Epoch 155/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4937 - mae: 3.9060
# Epoch 156/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.4371 - mae: 3.8448
# Epoch 157/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4424 - mae: 3.8486
# Epoch 158/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.3854 - mae: 3.7876
# Epoch 159/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3397 - mae: 3.7433
# Epoch 160/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3484 - mae: 3.7467
# Epoch 161/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.3654 - mae: 3.7675
# Epoch 162/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3989 - mae: 3.8028
# Epoch 163/200
# 30/30 [==============================] - 2s 53ms/step - loss: 3.7682 - mae: 4.1962
# Epoch 164/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3683 - mae: 3.7712
# Epoch 165/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3093 - mae: 3.7104
# Epoch 166/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.2989 - mae: 3.6980
# Epoch 167/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2717 - mae: 3.6708
# Epoch 168/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.2972 - mae: 3.6992
# Epoch 169/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.2821 - mae: 3.6850
# Epoch 170/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.2088 - mae: 3.6028
# Epoch 171/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3076 - mae: 3.7153
# Epoch 172/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.2095 - mae: 3.6046
# Epoch 173/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.3327 - mae: 3.7382
# Epoch 174/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2237 - mae: 3.6230
# Epoch 175/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3337 - mae: 3.7370
# Epoch 176/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.5345 - mae: 3.9524
# Epoch 177/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.4897 - mae: 3.9045
# Epoch 178/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1449 - mae: 3.5383
# Epoch 179/200
# 30/30 [==============================] - 2s 57ms/step - loss: 3.3760 - mae: 3.7843
# Epoch 180/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.1698 - mae: 3.5646
# Epoch 181/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1614 - mae: 3.5548
# Epoch 182/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1843 - mae: 3.5841
# Epoch 183/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4845 - mae: 3.8978
# Epoch 184/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.2313 - mae: 3.6358
# Epoch 185/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.3001 - mae: 3.7092
# Epoch 186/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.1667 - mae: 3.5650
# Epoch 187/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.0632 - mae: 3.4511
# Epoch 188/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1612 - mae: 3.5593
# Epoch 189/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.0579 - mae: 3.4487
# Epoch 190/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1963 - mae: 3.5975
# Epoch 191/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.1026 - mae: 3.4994
# Epoch 192/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.0664 - mae: 3.4588
# Epoch 193/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.0355 - mae: 3.4238
# Epoch 194/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2963 - mae: 3.7067
# Epoch 195/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.1754 - mae: 3.5789
# Epoch 196/200
# 30/30 [==============================] - 2s 56ms/step - loss: 3.1045 - mae: 3.4985
# Epoch 197/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1411 - mae: 3.5442
# Epoch 198/200
# 30/30 [==============================] - 2s 55ms/step - loss: 3.0550 - mae: 3.4476
# Epoch 199/200
# 30/30 [==============================] - 2s 54ms/step - loss: 3.1485 - mae: 3.5461
# Epoch 200/200
# 30/30 [==============================] - 2s 57ms/step - loss: 3.1102 - mae: 3.5107

# %%
rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()
# Out:
# 20.561346

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
#-----------------------------------------------------------
loss=history.history['loss']

epochs= range(len(loss)) # Get number of epochs

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.title('Training loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss"])

plt.figure()

zoomed_loss = loss[20:]
zoomed_epochs = epochs[20:]
plt.plot(zoomed_epochs, zoomed_loss, 'r')
plt.title('Training loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss"])
plt.show()

# %%
def model_forecast(model, series, window_size):
   ds = tf.data.Dataset.from_tensor_slices(series)
   ds = ds.window(window_size, shift=1, drop_remainder=True)
   ds = ds.flat_map(lambda w: w.batch(window_size))
   ds = ds.batch(32).prefetch(1)
   forecast = model.predict(ds)
   return forecast

rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

result = tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()
print(result)

plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecast)
plt.show()
# Out:
# 20.561346
